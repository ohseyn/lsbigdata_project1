# %%
import pandas as pd
import numpy as np

data = pd.read_csv('/content/시도별_화재발생_현황_총괄__20240711173609_1.csv')
data
# Out:
#       행정구역별    2020  2020.1  2020.2        2020.3     2020.4     2020.5  \
# 0     행정구역별  건수 (건)  사망 (명)  부상 (명)  재산피해(계) (천원)   부동산 (천원)    동산 (천원)
# 1        전국   38659     365    1918     600475432  226754018  373721414
# 2     서울특별시    5088      37     236      17438606    7298842   10139764
# 3     부산광역시    2499      13     166       5907121    1856165    4050956
# 4     대구광역시    1233      11      63       6463059    2893854    3569205
# 5     인천광역시    1368      22      66      11742584    5160008    6582576
# 6     광주광역시     882       4      28       3315188    1546647    1768541
# 7     대전광역시     865       8      57       7590112    3143954    4446158
# 8     울산광역시     910       9      66      16584280   11652678    4931602
# 9   세종특별자치시     203       2      16       3196125    1227512    1968613
# 10      경기도    8920     114     485     321982790  113081627  208901163
# 11      강원도    1847      18     113      23683248   10125593   13557655
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
print(data.columns)
# Out:
# Index(['행정구역별', '2020', '2020.1', '2020.2', '2020.3', '2020.4', '2020.5',
#        '2020.6', '2020.7', '2021', '2021.1', '2021.2', '2021.3', '2021.4',
#        '2021.5', '2021.6', '2021.7', '2022', '2022.1', '2022.2', '2022.3',
#        '2022.4', '2022.5', '2022.6', '2022.7'],
#       dtype='object')

# %%
data_2020 = data[['행정구역별'] + data.filter(like='2020').columns.tolist()]
data_2020
# Out:
#       행정구역별    2020  2020.1  2020.2        2020.3     2020.4     2020.5  \
# 0     행정구역별  건수 (건)  사망 (명)  부상 (명)  재산피해(계) (천원)   부동산 (천원)    동산 (천원)
# 1        전국   38659     365    1918     600475432  226754018  373721414
# 2     서울특별시    5088      37     236      17438606    7298842   10139764
# 3     부산광역시    2499      13     166       5907121    1856165    4050956
# 4     대구광역시    1233      11      63       6463059    2893854    3569205
# 5     인천광역시    1368      22      66      11742584    5160008    6582576
# 6     광주광역시     882       4      28       3315188    1546647    1768541
# 7     대전광역시     865       8      57       7590112    3143954    4446158
# 8     울산광역시     910       9      66      16584280   11652678    4931602
# 9   세종특별자치시     203       2      16       3196125    1227512    1968613
# 10      경기도    8920     114     485     321982790  113081627  208901163
# 11      강원도    1847      18     113      23683248   10125593   13557655
# ...

# %%
data_2020.columns = data_2020.iloc[0]

# %%
data_2020 = data_2020[1:]
data_2020 = data_2020.reset_index(drop=True)
data_2020
# Out:
# 0     행정구역별 건수 (건) 사망 (명) 부상 (명) 재산피해(계) (천원)   부동산 (천원)    동산 (천원)  \
# 0        전국  38659    365   1918    600475432  226754018  373721414
# 1     서울특별시   5088     37    236     17438606    7298842   10139764
# 2     부산광역시   2499     13    166      5907121    1856165    4050956
# 3     대구광역시   1233     11     63      6463059    2893854    3569205
# 4     인천광역시   1368     22     66     11742584    5160008    6582576
# 5     광주광역시    882      4     28      3315188    1546647    1768541
# 6     대전광역시    865      8     57      7590112    3143954    4446158
# 7     울산광역시    910      9     66     16584280   11652678    4931602
# 8   세종특별자치시    203      2     16      3196125    1227512    1968613
# 9       경기도   8920    114    485    321982790  113081627  208901163
# 10      강원도   1847     18    113     23683248   10125593   13557655
# 11     충청북도   1523     11    155     20516030    8295767   12220263
# 12     충청남도   2075     17     46     22357086    8057276   14299810
# ...

# %%
data_2020_pop = data_2020.iloc[:, 0:4]
data_2020_pop
# Out:
# 0     행정구역별 건수 (건) 사망 (명) 부상 (명)
# 0        전국  38659    365   1918
# 1     서울특별시   5088     37    236
# 2     부산광역시   2499     13    166
# 3     대구광역시   1233     11     63
# 4     인천광역시   1368     22     66
# 5     광주광역시    882      4     28
# 6     대전광역시    865      8     57
# 7     울산광역시    910      9     66
# 8   세종특별자치시    203      2     16
# 9       경기도   8920    114    485
# 10      강원도   1847     18    113
# 11     충청북도   1523     11    155
# 12     충청남도   2075     17     46
# 13     전라북도   2223     17     52
# 14     전라남도   2472     22     98
# 15     경상북도   2863     27    157
# 16     경상남도   3173     21    100
# 17  제주특별자치도    515     12     14

# %%
# 사망자 수와 부상자 수를 포함하는 새로운 데이터프레임 생성
data_plot = data_2020_pop[['행정구역별', '사망 (명)']]

# 막대 그래프 그리기
data_plot.set_index('행정구역별').plot(kind='bar')

# 그래프 제목과 축 라벨 설정
plt.title('행정구역별 사망자 수')
plt.ylabel('명')
plt.xlabel('행정구역')
plt.xticks(rotation=0)
plt.legend(title='종류')

# 그래프 출력
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-036973d5389e> in <cell line: 5>()
#       3
#       4 # 막대 그래프 그리기
# ----> 5 data_plot.set_index('행정구역별').plot(kind='bar')
#       6
#       7 # 그래프 제목과 축 라벨 설정
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     973                     data.columns = label_name
#     974
# --> 975         return plot_backend.plot(data, kind=kind, **kwargs)
#     976
#     977     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
data_2020_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   행정구역별   18 non-null     object
#  1   건수 (건)  18 non-null     object
#  2   사망 (명)  18 non-null     object
#  3   부상 (명)  18 non-null     object
# dtypes: object(4)
# memory usage: 704.0+ bytes

# %%
data_2020_pop['사망 (명)'] = pd.to_numeric(data_2020_pop['사망 (명)'])
data_2020_pop['부상 (명)'] = pd.to_numeric(data_2020_pop['부상 (명)'])
# Out:
# <ipython-input-10-17ba4388aec6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2020_pop['사망 (명)'] = pd.to_numeric(data_2020_pop['사망 (명)'])
# <ipython-input-10-17ba4388aec6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2020_pop['부상 (명)'] = pd.to_numeric(data_2020_pop['부상 (명)'])

# %%
data_2020_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   행정구역별   18 non-null     object
#  1   건수 (건)  18 non-null     object
#  2   사망 (명)  18 non-null     int64
#  3   부상 (명)  18 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 704.0+ bytes

# %%
import matplotlib.pyplot as plt
# 사망자 수 새로운 데이터프레임 생성
data_plot = data_2020_pop[['행정구역별', '사망 (명)']]

# 막대 그래프 그리기
data_plot.set_index('행정구역별').plot(kind='bar')

# 그래프 제목과 축 라벨 설정
plt.title('행정구역별 사망자 수')
plt.ylabel('명')
plt.xlabel('행정구역')
plt.xticks(rotation=0)
plt.legend(title='종류')
plt.xticks(rotation=90)

# 그래프 출력
plt.show()

# %%
import matplotlib.pyplot as plt

# 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic')

# %%
plt.figure(figsize=(6,4))
plt.text(0.5, 0.5, '한글 폰트 테스트', size=15)
plt.show()

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...
